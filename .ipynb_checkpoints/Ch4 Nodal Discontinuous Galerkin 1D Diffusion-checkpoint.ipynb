# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Reloading the module
import importlib

import OrthogonalPolynomials
importlib.reload(OrthogonalPolynomials)
from OrthogonalPolynomials import *

import GeneralFunctionality
importlib.reload(GeneralFunctionality)
from GeneralFunctionality import *

from scipy.special import eval_legendre, roots_legendre
from scipy import integrate

# %%
# Finding the Legendre Gauss points
N = 40
# Node index: 0,1,...,N -> N+1 nodes -> zeros of L_{N+1}
x_Le, w_Le = roots_legendre(N+1)
# Barycentric weights
w_bary = BarycentricWeights(x_Le)
# Differentiation matrix
D = PolynomialDiffMatrix(x_Le, w_bary)
# 2nd-order differentiation matrix
D2 = PolynomialDiffMatrix_HighOrder(2, x_Le, w_bary, D)

# %%
def MatrixG(N, D2, w): 
    # Computing the matrix G on the RHS of the ODE system
    # D2: 2nd-order differentiation matrix
    # w: Legendre Gauss weights
    # The subroutine can be improved by numpy vectorization
    
    G = np.zeros((N+1, N+1))
    for j in range(N+1):
        for n in range(N+1):
            G[j,n] = D2[n,j] * w[n] / w[j]
            
    return G

G = MatrixG(N, D2, w_Le)

# %%
def MatrixG_ver2(N, D, w): 
    # Computing the matrix G on the RHS of the ODE system
    # D2: 2nd-order differentiation matrix
    # w: Legendre Gauss weights
    # The subroutine can be improved by numpy vectorization
    
    G = np.zeros((N+1, N+1))
    for j in range(N+1):
        for m in range(N+1):
            for k in range(N+1):
                G[j,m] += w[k] * D[k,m] * D[k,j]
            G[j,m] /= w[j]
            
    return G

G = MatrixG_ver2(N, D2, w_Le)

# %%
def LagrangePolynomialsBoundaryValues(N, x_nodes, w_bary):
    # Computing l_j(-1), l_j(1) for j=0,1,...,N
    # x_nodes: interpolating nodes
    # w_bary: barycentric weights
    
    l_left = np.zeros(N+1)
    l_right = np.zeros(N+1)
    
    for j in range(N+1):
        l_left[j] = LagrangePolynomialBary(j, -1.0, x_nodes, w_bary)
        l_right[j] = LagrangePolynomialBary(j, 1.0, x_nodes, w_bary)
    
    return l_left, l_right

l_left, l_right = LagrangePolynomialsBoundaryValues(N, x_Le, w_bary)

# %%
def RHS1(t, u, N, x_Le, w_Le, w_bary, D, G, l_left, l_right):
    # Evaluating the RHS of the ODE system
    
    # Derivatives of the interpolating polynomial at the boundaries
    ux_left = LagrangeInterpolationDerivativeBary(-1.0, x_Le, u, w_bary, D)
    ux_right = LagrangeInterpolationDerivativeBary(1.0, x_Le, u, w_bary, D)
    
    
    rhs = (ux_right*l_right - ux_left*l_left) / w_Le + np.dot(G, u)
    
    return rhs

# %%
def RHS_ver2(t, u, N, x_Le, w_Le, w_bary, D, G, l_left, l_right):
    # Evaluating the RHS of the ODE system
    
    # Derivatives of the interpolating polynomial at the boundaries
    ux_left = LagrangeInterpolationDerivativeBary(-1.0, x_Le, u, w_bary, D)
    ux_right = LagrangeInterpolationDerivativeBary(1.0, x_Le, u, w_bary, D)
    
    
    rhs = (ux_right*l_right - ux_left*l_left) / w_Le - np.dot(G, u)
    
    return rhs

# %%
u = 1 - x_Le**2
dt = 0.01

for step in range(3):
    u = u + dt * RHS(0, u, N, x_Le, w_Le, w_bary, D, G, l_left, l_right)

# %%
u
# Out:
# array([-164685.88013834,   53385.7081182 ,  -30351.52064199,
#          20385.62439098,  -14899.01899388,   11540.25445482,
#          -9328.66490657,    7793.85124823,   -6684.03694396,
#           5858.68422467,   -5228.46479259,    4741.92869229,
#          -4358.83665135,    4059.2198021 ,   -3820.77018785,
#           3637.09924023,   -3493.38849344,    3390.10536975,
#          -3316.04142375,    3275.59725306,   -3259.79653647,
#           3275.59725309,   -3316.04142381,    3390.10536984,
#          -3493.38849357,    3637.0992404 ,   -3820.77018806,
#           4059.21980236,   -4358.83665166,    4741.92869266,
#          -5228.46479304,    5858.68422521,   -6684.03694462,
#           7793.85124904,   -9328.66490758,   11540.25445612,
#         -14899.01899562,   20385.62439343,  -30351.52064571,
#          53385.70812459, -164685.88015586])

# %%
# Scipy calculation

# Initial condition
u0 = 1 - x_Le**2

t_span = [0, 1]
t_eval=[0, 0.005]
sol = solve_ivp(RHS, 
                t_span=t_span, 
                y0=u0, 
                method='RK45', 
                t_eval=t_eval, 
                args=(N, x_Le, w_Le, w_bary, D, G, l_left, l_right))

fig = plt.figure()
ax = fig.add_subplot(111)

Nt = len(t_eval)
for it in range(Nt):
    ax.plot(x_Le, sol.y[:,it], label='t={}'.format(t_eval[it]))

ax.legend()
ax.set_title(r'$u_t=u_{xx}$')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12864\1246326802.py in <module>
#      18 Nt = len(t_eval)
#      19 for it in range(Nt):
# ---> 20     ax.plot(x_Le, sol.y[:,it], label='t={}'.format(t_eval[it]))
#      21
#      22 ax.legend()
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
# Interpolating to a finer grid for plotting purpose
y = np.linspace(-1,1,101)
T = InterpolatingMatrix(x_Le, y, w_bary)

fig = plt.figure()
ax = fig.add_subplot(111)

Nt = len(t_eval)
for it in range(Nt):
    u = sol.y[:,it]
    u_newgrid = np.dot(T, u)
    ax.plot(y, u_newgrid, label='t={}'.format(t_eval[it]))


ax.legend()
ax.set_title(r'$u_t=u_{xx}$')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12864\3986372218.py in <module>
#       8 Nt = len(t_eval)
#       9 for it in range(Nt):
# ---> 10     u = sol.y[:,it]
#      11     u_newgrid = np.dot(T, u)
#      12     ax.plot(y, u_newgrid, label='t={}'.format(t_eval[it]))
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
